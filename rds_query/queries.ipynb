# %%
from SPARQLWrapper import SPARQLWrapper, JSON, CSV
import io
import pandas as pd
sparql = SPARQLWrapper("http://localhost:3030/graph")

package = input('Package you want to find')
version = input('version')
if version == '':
  sparql.setQuery("""
  PREFIX sd: <https://w3id.org/okn/o/sd#>
  prefix c2t: <https://w3id.org/c2t#> 
  prefix c2ti: <https://w3id.org/c2t/i/> 
  prefix dc: <http://purl.org/dc/elements/1.1/> 
  prefix dpv: <http://dockerpedia.inf.utfsm.cl/vocab#> 
  prefix owl: <http://www.w3.org/2002/07/owl#> 
  prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  prefix rr: <http://www.w3.org/ns/r2rml#> 
  prefix rml: <http://semweb.mmlab.be/ns/rml#> 
  prefix ql: <http://semweb.mmlab.be/ns/ql#> 
  prefix : <http://example.org/> 


  SELECT ?tag
  WHERE {
    # ?o a dpv:PackageVersion.
    # ?o sd:name '"""+package+"""'.
    # ?o dpv:isInstalledOn ?image.
    # ?image dpv:tag ?tag
  } 
  """)
else:
  sparql.setQuery("""
  PREFIX sd: <https://w3id.org/okn/o/sd#>
  prefix c2t: <https://w3id.org/c2t#> 
  prefix c2ti: <https://w3id.org/c2t/i/> 
  prefix dc: <http://purl.org/dc/elements/1.1/> 
  prefix dpv: <http://dockerpedia.inf.utfsm.cl/vocab#> 
  prefix owl: <http://www.w3.org/2002/07/owl#> 
  prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
  prefix rr: <http://www.w3.org/ns/r2rml#> 
  prefix rml: <http://semweb.mmlab.be/ns/rml#> 
  prefix ql: <http://semweb.mmlab.be/ns/ql#> 
  prefix : <http://example.org/> 


  SELECT ?tag
  WHERE {
    # ?o a dpv:PackageVersion.
    # ?o sd:name '"""+package+"""'.
    # ?o sd:hasVersionId '"""+version+"""'.
    # ?o dpv:isInstalledOn ?image.
    # ?image dpv:tag ?tag.
    # ?image 
  } 
  """)
sparql.setReturnFormat(CSV)
results_lib = sparql.query().convert()
results_2lib = io.StringIO(results_lib.decode('utf-8'))
lib_results = pd.read_csv(results_2lib)
print(lib_results)
# Out:
# Empty DataFrame
# Columns: [tag]
# Index: []

# %%
image = input('Image')
sparql.setQuery("""
PREFIX sd: <https://w3id.org/okn/o/sd#>
prefix c2t: <https://w3id.org/c2t#> 
prefix c2ti: <https://w3id.org/c2t/i/> 
prefix dc: <http://purl.org/dc/elements/1.1/> 
prefix dpv: <http://dockerpedia.inf.utfsm.cl/vocab#> 
prefix owl: <http://www.w3.org/2002/07/owl#> 
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
prefix rr: <http://www.w3.org/ns/r2rml#> 
prefix rml: <http://semweb.mmlab.be/ns/rml#> 
prefix ql: <http://semweb.mmlab.be/ns/ql#> 
prefix dct: <https://purl.org/dc/terms/> 
prefix : <http://example.org/> 

SELECT ?tag ?architecture ?size ?osDescription ?created
WHERE { ?image a dpv:Image.
  # ?image dpv:tag '"""+image+"""'.
  # ?image dpv:tag ?tag.
  # ?os c2t:isOperativeSystemOf ?image .
  # ?image c2t:architecture ?architecture .
  # ?image dpv:size ?size .
  # ?os sd:description ?osDescription .
  # ?image c2t:created ?created.  
} 
""")
results_im = sparql.query().convert()
results_2im = io.StringIO(results_im.decode('utf-8'))
im_results = pd.read_csv(results_2im)
print(im_results)


sparql.setQuery("""
PREFIX sd: <https://w3id.org/okn/o/sd#>
prefix c2t: <https://w3id.org/c2t#> 
prefix c2ti: <https://w3id.org/c2t/i/> 
prefix dc: <http://purl.org/dc/elements/1.1/> 
prefix dpv: <http://dockerpedia.inf.utfsm.cl/vocab#> 
prefix owl: <http://www.w3.org/2002/07/owl#> 
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix rr: <http://www.w3.org/ns/r2rml#> 
prefix rml: <http://semweb.mmlab.be/ns/rml#> 
prefix ql: <http://semweb.mmlab.be/ns/ql#> 
prefix dct: <https://purl.org/dc/terms/> 
prefix : <http://example.org/> 

SELECT ?packageT (COUNT(?package) as ?total)
WHERE {
    # ?image a dpv:Image.
    # ?image dpv:tag '"""+image+"""'.
	# ?package dpv:isInstalledOn ?image;
			c2t:operativeSystemPackageVersion ?packageT .
}GROUP BY (?packageT)
""")
results_pa = sparql.query().convert()
results_2pa = io.StringIO(results_pa.decode('utf-8'))
pa_results = pd.read_csv(results_2pa)
print(pa_results)
# Out:
#                                                image           tag  \
# 0  https://w3id.org/c2t/i/sha256%3Ac8b57c4bf7e3a8...  mongo:latest
#
#   architecture       size       osDescription                         created
# 0        amd64  701471245  Ubuntu 20.04.4 LTS  2022-06-13T22:08:51.667362387Z
#     packageT  total
# 0  go-module     20
# 1        deb    153

# %%
image = input('Image')
image2 = input('Image')
sparql.setQuery("""
PREFIX sd: <https://w3id.org/okn/o/sd#>
prefix c2t: <https://w3id.org/c2t#> 
prefix c2ti: <https://w3id.org/c2t/i/> 
prefix dc: <http://purl.org/dc/elements/1.1/> 
prefix dpv: <http://dockerpedia.inf.utfsm.cl/vocab#> 
prefix owl: <http://www.w3.org/2002/07/owl#> 
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
prefix rr: <http://www.w3.org/ns/r2rml#> 
prefix rml: <http://semweb.mmlab.be/ns/rml#> 
prefix ql: <http://semweb.mmlab.be/ns/ql#> 
prefix dct: <https://purl.org/dc/terms/> 
prefix : <http://example.org/> 

SELECT ?image  ?tag ?architecture ?size ?osDescription ?created
WHERE { ?image a dpv:Image.
  # ?image dpv:tag '"""+image+"""'.
  # ?image dpv:tag ?tag.
  # ?os c2t:isOperativeSystemOf ?image .
  # ?image c2t:architecture ?architecture .
  # ?image dpv:size ?size .
  # ?os sd:description ?osDescription .
  # ?image c2t:created ?created.  
} 
""")
results_im = sparql.query().convert()
results_2im = io.StringIO(results_im.decode('utf-8'))
im_results = pd.read_csv(results_2im)
print(im_results)


sparql.setQuery("""
PREFIX sd: <https://w3id.org/okn/o/sd#>
prefix c2t: <https://w3id.org/c2t#> 
prefix c2ti: <https://w3id.org/c2t/i/> 
prefix dc: <http://purl.org/dc/elements/1.1/> 
prefix dpv: <http://dockerpedia.inf.utfsm.cl/vocab#> 
prefix owl: <http://www.w3.org/2002/07/owl#> 
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix rr: <http://www.w3.org/ns/r2rml#> 
prefix rml: <http://semweb.mmlab.be/ns/rml#> 
prefix ql: <http://semweb.mmlab.be/ns/ql#> 
prefix dct: <https://purl.org/dc/terms/> 
prefix : <http://example.org/> 

SELECT ?package
WHERE {
    # ?image a dpv:Image.
    # ?image dpv:tag '"""+image+"""'.
	# ?package dpv:isInstalledOn ?image
}
""")
results_pa = sparql.query().convert()
results_2pa = io.StringIO(results_pa.decode('utf-8'))
pa_results = pd.read_csv(results_2pa)
print(pa_results)

sparql.setQuery("""
PREFIX sd: <https://w3id.org/okn/o/sd#>
prefix c2t: <https://w3id.org/c2t#> 
prefix c2ti: <https://w3id.org/c2t/i/> 
prefix dc: <http://purl.org/dc/elements/1.1/> 
prefix dpv: <http://dockerpedia.inf.utfsm.cl/vocab#> 
prefix owl: <http://www.w3.org/2002/07/owl#> 
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
prefix rr: <http://www.w3.org/ns/r2rml#> 
prefix rml: <http://semweb.mmlab.be/ns/rml#> 
prefix ql: <http://semweb.mmlab.be/ns/ql#> 
prefix dct: <https://purl.org/dc/terms/> 
prefix : <http://example.org/> 

SELECT ?image  ?tag ?architecture ?size ?osDescription ?created
WHERE { ?image a dpv:Image.
  # ?image dpv:tag '"""+image2+"""'.
  # ?image dpv:tag ?tag.
  # ?os c2t:isOperativeSystemOf ?image .
  # ?image c2t:architecture ?architecture .
  # ?image dpv:size ?size .
  # ?os sd:description ?osDescription .
  # ?image c2t:created ?created.  
} 
""")
results_im = sparql.query().convert()
results_2im = io.StringIO(results_im.decode('utf-8'))
im_results = pd.read_csv(results_2im)
print(im_results)


sparql.setQuery("""
PREFIX sd: <https://w3id.org/okn/o/sd#>
prefix c2t: <https://w3id.org/c2t#> 
prefix c2ti: <https://w3id.org/c2t/i/> 
prefix dc: <http://purl.org/dc/elements/1.1/> 
prefix dpv: <http://dockerpedia.inf.utfsm.cl/vocab#> 
prefix owl: <http://www.w3.org/2002/07/owl#> 
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix rr: <http://www.w3.org/ns/r2rml#> 
prefix rml: <http://semweb.mmlab.be/ns/rml#> 
prefix ql: <http://semweb.mmlab.be/ns/ql#> 
prefix dct: <https://purl.org/dc/terms/> 
prefix : <http://example.org/> 

SELECT ?package
WHERE {
    # ?image a dpv:Image.
    # ?image dpv:tag '"""+image2+"""'.
	  # ?package dpv:isInstalledOn ?image
}
""")
results_pa = sparql.query().convert()
results_2pa = io.StringIO(results_pa.decode('utf-8'))
pa_results = pd.read_csv(results_2pa)
print(pa_results)
# Out:
#                                                image           tag  \
# 0  https://w3id.org/c2t/i/sha256%3Ac8b57c4bf7e3a8...  mongo:latest
#
#   architecture       size       osDescription                         created
# 0        amd64  701471245  Ubuntu 20.04.4 LTS  2022-06-13T22:08:51.667362387Z
#                                                package
# 0    https://w3id.org/c2t/i/PackageVersion/pkg%3Ade...
# 1    https://w3id.org/c2t/i/PackageVersion/pkg%3Ade...
# 2    https://w3id.org/c2t/i/PackageVersion/pkg%3Ade...
# 3    https://w3id.org/c2t/i/PackageVersion/pkg%3Ade...
# 4    https://w3id.org/c2t/i/PackageVersion/pkg%3Ago...
# ..                                                 ...
# 168  https://w3id.org/c2t/i/PackageVersion/pkg%3Ade...
# 169  https://w3id.org/c2t/i/PackageVersion/pkg%3Ade...
# 170  https://w3id.org/c2t/i/PackageVersion/pkg%3Ade...
# 171  https://w3id.org/c2t/i/PackageVersion/pkg%3Ade...
# 172  https://w3id.org/c2t/i/PackageVersion/pkg%3Ade...
#
# [173 rows x 1 columns]
#                                                image           tag  \
# 0  https://w3id.org/c2t/i/sha256%3A33037edcac9b15...  mysql:latest
#
#   architecture       size            osDescription  \
# 0        amd64  443989708  Oracle Linux Server 8.6
#
#                           created
# 0  2022-07-13T06:46:11.919327635Z
#                                                package
# 0    https://w3id.org/c2t/i/PackageVersion/pkg%3Arp...
# 1    https://w3id.org/c2t/i/PackageVersion/pkg%3Arp...
# 2    https://w3id.org/c2t/i/PackageVersion/pkg%3Arp...
# 3    https://w3id.org/c2t/i/PackageVersion/pkg%3Arp...
# 4    https://w3id.org/c2t/i/PackageVersion/pkg%3Ago...
# ..                                                 ...
# 131  https://w3id.org/c2t/i/PackageVersion/pkg%3Arp...
# 132  https://w3id.org/c2t/i/PackageVersion/pkg%3Apy...
# 133  https://w3id.org/c2t/i/PackageVersion/pkg%3Arp...
# 134  https://w3id.org/c2t/i/PackageVersion/pkg%3Arp...
# 135  https://w3id.org/c2t/i/PackageVersion/pkg%3Apy...
#
# [136 rows x 1 columns]
